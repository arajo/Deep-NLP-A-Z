# %%
from convokit import Corpus, download

corpus = Corpus(filename=download("movie-corpus"))
# Out:
# Downloading movie-corpus to /Users/ara/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done

# %%
corpus.print_summary_stats()
# Out:
# Number of Speakers: 9035
# Number of Utterances: 304713
# Number of Conversations: 83097

# %%
corpus.corpus_dirpath
# Out:
# '/Users/ara/.convokit/downloads/movie-corpus'

# %%
corpus.get_conversations_dataframe()
# Out:
#         vectors meta.movie_idx             meta.movie_name meta.release_year  \
# id
# L1044        []             m0  10 things i hate about you              1999
# L984         []             m0  10 things i hate about you              1999
# L924         []             m0  10 things i hate about you              1999
# L870         []             m0  10 things i hate about you              1999
# L866         []             m0  10 things i hate about you              1999
# ...         ...            ...                         ...               ...
# L666324      []           m616                   zulu dawn              1979
# L666262      []           m616                   zulu dawn              1979
# L666520      []           m616                   zulu dawn              1979
# L666369      []           m616                   zulu dawn              1979
# L666256      []           m616                   zulu dawn              1979
#
#         meta.rating meta.votes  \
# id
# L1044          6.90      62847
# L984           6.90      62847
# L924           6.90      62847
# L870           6.90      62847
# L866           6.90      62847
# ...             ...        ...
# L666324        6.40       1911
# L666262        6.40       1911
# L666520        6.40       1911
# L666369        6.40       1911
# L666256        6.40       1911
#
#                                                 meta.genre
# id
# L1044                                ['comedy', 'romance']
# L984                                 ['comedy', 'romance']
# L924                                 ['comedy', 'romance']
# L870                                 ['comedy', 'romance']
# L866                                 ['comedy', 'romance']
# ...                                                    ...
# L666324  ['action', 'adventure', 'drama', 'history', 'w...
# L666262  ['action', 'adventure', 'drama', 'history', 'w...
# L666520  ['action', 'adventure', 'drama', 'history', 'w...
# L666369  ['action', 'adventure', 'drama', 'history', 'w...
# L666256  ['action', 'adventure', 'drama', 'history', 'w...
#
# [83097 rows x 7 columns]

# %%
corpus.get_conversation_ids()
# Out:
# ['L1044',
#  'L984',
#  'L924',
#  'L870',
#  'L866',
#  'L862',
#  'L860',
#  'L696',
#  'L693',
#  'L662',
#  'L577',
#  'L575',
#  'L404',
#  'L401',
#  'L367',
#  'L365',
#  'L363',
#  'L280',
#  'L276',
#  'L271',
#  'L207',
#  'L204',
#  'L200',
#  'L198',
#  'L194',
#  'L952',
#  'L659',
#  'L598',
#  'L595',
#  'L579',
#  'L571',
#  'L49',
#  'L759',
#  'L756',
#  'L592',
#  'L589',
#  'L396',
#  'L394',
#  'L1051',
#  'L1021',
#  'L1007',
#  'L982',
#  'L909',
#  'L904',
#  'L901',
#  'L893',
#  'L889',
#  'L655',
#  'L601',
#  'L542',
#  'L531',
#  'L529',
#  'L525',
#  'L441',
#  'L319',
#  'L164',
#  'L922',
#  'L878',
#  'L544',
#  'L538',
#  'L536',
#  'L523',
#  'L517',
#  'L189',
#  'L179',
#  'L458',
#  'L778',
#  'L583',
#  'L499',
#  'L432',
#  'L424',
#  'L416',
#  'L388',
#  'L244',
#  'L223',
#  'L215',
#  'L212',
#  'L210',
#  'L157',
#  'L143',
#  'L139',
#  'L87',
#  'L77',
#  'L66',
#  'L63',
#  'L780',
#  'L743',
#  'L740',
#  'L725',
#  'L623',
#  'L621',
#  'L619',
#  'L430',
#  'L426',
#  'L411',
#  'L385',
#  'L557',
#  'L554',
#  'L335',
#  'L148',
#  'L747',
#  'L607',
#  'L605',
#  'L354',
#  'L349',
#  'L300',
#  'L298',
#  'L294',
#  'L287',
#  'L285',
#  'L508',
#  'L502',
#  'L238',
#  'L231',
#  'L946',
#  'L750',
#  'L716',
#  'L490',
#  'L447',
#  'L252',
#  'L247',
#  'L151',
#  'L133',
#  'L131',
#  'L129',
#  'L123',
#  'L1040',
#  'L1033',
#  'L1031',
#  'L973',
#  'L960',
#  'L957',
#  'L936',
#  'L852',
#  'L842',
#  'L834',
#  'L828',
#  'L824',
#  'L813',
#  'L808',
#  'L803',
#  'L800',
#  'L798',
#  'L769',
#  'L764',
#  'L686',
#  'L683',
#  'L680',
#  'L677',
#  'L670',
#  'L668',
#  'L650',
#  'L639',
#  'L626',
#  'L612',
#  'L610',
#  'L564',
#  'L481',
#  'L475',
#  'L473',
#  'L333',
#  'L330',
#  'L322',
#  'L311',
#  'L309',
#  'L304',
#  'L998',
#  'L989',
#  'L986',
#  'L338',
#  'L184',
#  'L172',
#  'L1017',
#  'L108',
#  'L103',
#  'L735',
#  'L732',
#  'L728',
#  'L775',
#  'L723',
#  'L436',
#  'L428',
#  'L420',
#  'L414',
#  'L383',
#  'L380',
#  'L378',
#  'L375',
#  'L371',
#  'L511',
#  'L261',
#  'L257',
#  'L59',
#  'L929',
#  'L926',
#  'L917',
#  'L886',
#  'L876',
#  'L191',
#  'L170',
#  'L161',
#  'L2179',
#  'L2176',
#  'L2173',
#  'L2170',
#  'L2024',
#  'L2022',
#  'L2019',
#  'L2014',
#  'L2010',
#  'L2005',
#  'L1989',
#  'L2522',
#  'L2274',
#  'L2030',
#  'L2027',
#  'L2539',
#  'L2537',
#  'L2473',
#  'L2471',
#  'L2318',
#  'L2121',
#  'L2118',
#  'L1985',
#  'L1979',
#  'L2429',
#  'L2423',
#  'L2421',
#  'L2290',
#  'L2550',
#  'L2547',
#  'L2541',
#  'L2500',
#  'L2484',
#  'L2439',
#  'L2130',
#  'L2127',
#  'L2467',
#  'L2465',
#  'L2463',
#  'L2299',
#  'L2295',
#  'L2286',
#  'L2281',
#  'L2109',
#  'L2106',
#  'L2103',
#  'L2409',
#  'L2393',
#  'L2341',
#  'L2256',
#  'L2253',
#  'L2248',
#  'L2237',
#  'L2531',
#  'L2525',
#  'L2144',
#  'L2140',
#  'L2134',
#  'L2132',
#  'L2045',
#  'L2041',
#  'L2037',
#  'L1963',
#  'L1957',
#  'L1951',
#  'L1947',
#  'L1942',
#  'L2456',
#  'L2279',
#  'L2085',
#  'L2079',
#  'L2076',
#  'L2073',
#  'L2071',
#  'L2386',
#  'L2347',
#  'L2345',
#  'L2331',
#  'L2328',
#  'L2277',
#  'L2490',
#  'L2164',
#  'L2157',
#  'L2154',
#  'L2196',
#  'L2064',
#  'L2460',
#  'L2417',
#  'L2414',
#  'L2376',
#  'L2115',
#  'L2112',
#  'L1930',
#  'L3545',
#  'L3496',
#  'L3490',
#  'L3482',
#  'L3464',
#  'L3459',
#  'L3392',
#  'L3383',
#  'L3380',
#  'L3514',
#  'L3329',
#  'L3315',
#  'L3313',
#  'L3309',
#  'L3305',
#  'L3300',
#  'L3177',
#  'L3167',
#  'L3161',
#  'L3158',
#  'L3096',
#  'L3093',
#  'L3089',
#  'L3059',
#  'L3062',
#  'L3055',
#  'L3049',
#  'L3045',
#  'L3208',
#  'L3498',
#  'L3293',
#  'L3198',
#  'L3196',
#  'L2797',
#  'L3289',
#  'L2801',
#  'L3027',
#  'L3022',
#  'L3016',
#  'L2936',
#  'L2924',
#  'L2920',
#  'L2751',
#  'L2630',
#  'L2602',
#  'L2599',
#  'L2986',
#  'L2979',
#  'L2975',
#  'L2971',
#  'L2964',
#  'L3229',
#  'L3223',
#  'L3219',
#  'L3080',
#  'L3069',
#  'L3067',
#  'L3057',
#  'L3052',
#  'L2993',
#  'L2991',
#  'L2962',
#  'L2955',
#  'L2949',
#  'L2899',
#  'L2895',
#  'L2892',
#  'L2887',
#  'L2883',
#  'L2875',
#  'L2746',
#  'L2730',
#  'L3248',
#  'L3243',
#  'L3236',
#  'L3148',
#  'L3135',
#  'L3126',
#  'L3119',
#  'L3103',
#  'L3101',
#  'L3038',
#  'L3031',
#  'L3029',
#  'L2758',
#  'L2664',
#  'L2653',
#  'L2651',
#  'L2646',
#  'L2644',
#  'L2611',
#  'L2604',
#  'L2595',
#  'L2627',
#  'L2621',
#  'L3278',
#  'L3554',
#  'L3435',
#  'L3433',
#  'L3431',
#  'L3419',
#  'L2857',
#  'L2855',
#  'L2850',
#  'L2848',
#  'L2845',
#  'L2577',
#  'L2570',
#  'L2565',
#  'L2563',
#  'L2910',
#  'L2908',
#  'L3547',
#  'L3376',
#  'L3372',
#  'L3368',
#  'L3365',
#  'L3363',
#  'L3361',
#  'L3359',
#  'L3356',
#  'L3250',
#  'L3246',
#  'L3191',
#  'L3189',
#  'L3183',
#  'L3087',
#  'L3083',
#  'L2842',
#  'L2789',
#  'L2780',
#  'L2778',
#  'L2670',
#  'L2666',
#  'L2639',
#  'L2635',
#  'L2561',
#  'L2559',
#  'L2557',
#  'L2685',
#  'L2680',
#  'L2678',
#  'L2674',
#  'L2672',
#  'L3352',
#  'L3271',
#  'L3411',
#  'L3409',
#  'L2614',
#  'L2608',
#  'L3262',
#  'L2582',
#  'L2575',
#  'L3398',
#  'L2744',
#  'L2740',
#  'L2732',
#  'L2771',
#  'L2706',
#  'L2701',
#  'L2698',
#  'L2808',
#  'L3342',
#  'L3287',
#  'L3024',
#  'L2870',
#  'L2863',
#  'L2793',
#  'L2767',
#  'L2754',
#  'L2738',
#  'L2735',
#  'L2724',
#  'L2715',
#  'L3425',
#  'L3422',
#  'L2928',
#  'L2828',
#  'L3777',
#  'L3770',
#  'L3756',
#  'L3749',
#  'L3728',
#  'L3720',
#  'L3712',
#  'L4296',
#  'L4282',
#  'L4208',
#  'L4196',
#  'L4188',
#  'L4159',
#  'L4011',
#  'L3995',
#  'L3987',
#  'L3979',
#  'L3972',
#  'L3963',
#  'L3942',
#  'L4366',
#  'L4360',
#  'L4353',
#  'L4346',
#  'L4333',
#  'L4265',
#  'L4227',
#  'L4219',
#  'L4079',
#  'L4068',
#  'L4006',
#  'L4018',
#  'L4009',
#  'L4002',
#  'L3993',
#  'L3977',
#  'L3970',
#  'L3688',
#  'L3679',
#  'L3672',
#  'L3668',
#  'L3805',
#  'L3797',
#  'L3779',
#  'L3774',
#  'L3758',
#  'L3730',
#  'L3651',
#  'L3626',
#  'L3622',
#  'L3772',
#  'L3766',
#  'L3760',
#  'L3751',
#  'L3745',
#  'L3738',
#  'L3724',
#  'L3904',
#  'L3896',
#  'L3889',
#  'L3868',
#  'L3837',
#  'L3832',
#  'L3824',
#  'L3817',
#  'L4181',
#  'L4174',
#  'L4169',
#  'L4118',
#  'L4108',
#  'L4096',
#  'L4028',
#  'L4020',
#  'L5045',
#  'L5043',
#  'L5041',
#  'L5039',
#  'L4924',
#  'L4922',
#  'L4903',
#  'L4897',
#  'L4567',
#  'L4562',
#  'L4506',
#  'L4501',
#  'L4453',
#  'L5370',
#  'L5366',
#  'L5215',
#  'L5193',
#  'L5183',
#  'L5181',
#  'L5175',
#  'L5328',
#  'L5321',
#  'L5316',
#  'L4959',
#  'L4944',
#  'L5346',
#  'L5338',
#  'L4628',
#  'L5383',
#  'L5377',
#  'L5375',
#  'L5372',
#  'L5351',
#  'L5308',
#  'L5306',
#  'L5304',
#  'L5290',
#  'L5256',
#  'L5253',
#  'L5249',
#  'L5236',
#  'L5224',
#  'L5212',
#  'L5208',
#  'L5206',
#  'L5204',
#  'L5201',
#  'L5197',
#  'L5195',
#  'L5190',
#  'L5171',
#  'L5083',
#  'L5076',
#  'L5073',
#  'L5069',
#  'L5067',
#  'L5065',
#  'L5060',
#  'L5057',
#  'L5052',
#  'L5049',
#  'L5036',
#  'L5033',
#  'L5028',
#  'L5023',
#  'L5021',
#  'L5018',
#  'L5016',
#  'L5011',
#  'L5007',
#  'L5002',
#  'L4994',
#  'L4974',
#  'L4969',
#  'L4964',
#  'L4937',
#  'L4929',
#  'L4911',
#  'L4895',
#  'L4893',
#  'L4887',
#  'L4882',
#  'L4880',
#  'L4873',
#  'L4870',
#  'L4868',
#  'L4866',
#  'L4863',
#  'L4860',
#  'L4857',
#  'L4848',
#  'L4825',
#  'L4814',
#  'L4800',
#  'L4789',
#  'L4786',
#  'L4780',
#  'L4778',
#  'L4771',
#  'L4769',
#  'L4765',
#  'L4763',
#  'L4743',
#  'L4739',
#  'L4731',
#  'L4727',
#  'L5244',
#  'L5242',
#  'L5102',
#  'L5100',
#  'L5097',
#  'L5093',
#  'L4693',
#  'L4691',
#  'L4689',
#  'L4642',
#  'L4636',
#  'L5162',
#  'L5158',
#  'L5144',
#  'L5142',
#  'L5132',
#  'L4685',
#  'L4681',
#  'L4677',
#  'L4675',
#  'L4672',
#  'L4669',
#  'L4821',
#  'L4817',
#  'L4809',
#  'L5364',
#  'L5359',
#  'L5355',
#  'L5301',
#  'L5292',
#  'L5284',
#  'L5275',
#  'L5258',
#  'L5219',
#  'L5167',
#  'L5164',
#  'L5149',
#  'L4839',
#  'L4836',
#  'L4712',
#  'L4707',
#  'L4704',
#  'L4533',
#  'L4528',
#  'L4523',
#  'L4519',
#  'L4516',
#  'L4513',
#  'L4477',
#  'L4475',
#  'L4472',
#  'L4469',
#  'L4467',
#  'L5288',
#  'L5279',
#  'L5266',
#  'L5264',
#  'L4612',
#  'L4609',
#  'L4603',
#  'L4600',
#  'L4495',
#  'L4493',
#  'L5233',
#  'L5230',
#  'L4558',
#  'L4548',
#  'L4543',
#  'L5124',
#  'L5121',
#  'L5115',
#  'L5113',
#  'L5109',
#  'L5107',
#  'L5105',
#  'L5889',
#  'L5875',
#  'L5692',
#  'L5678',
#  'L5673',
#  'L5643',
#  'L5760',
#  'L5754',
#  'L5751',
#  'L5746',
#  'L5737',
#  'L5710',
#  'L6263',
#  'L6258',
#  'L6168',
#  'L5839',
#  'L5826',
#  'L5656',
#  'L5652',
#  'L5648',
#  'L5624',
#  'L5620',
#  'L5615',
#  'L5613',
#  'L5556',
#  'L5521',
#  'L5515',
#  'L5511',
#  'L5508',
#  'L5468',
#  'L5463',
#  'L6251',
#  'L5911',
#  'L5730',
#  'L5688',
#  'L5686',
#  'L5675',
#  'L5671',
#  'L5646',
#  'L5636',
#  'L5630',
#  'L6123',
#  'L6114',
#  'L6108',
#  'L6105',
#  'L5669',
#  'L5664',
#  'L5501',
#  'L5497',
#  'L5493',
#  'L5490',
#  'L5488',
#  'L5638',
#  'L5633',
#  'L5611',
#  'L5609',
#  'L5605',
#  'L5596',
#  'L5426',
#  'L5422',
#  'L5420',
#  'L6029',
#  'L5880',
#  'L5790',
#  'L5787',
#  'L5785',
#  'L5782',
#  'L5777',
#  'L6211',
#  'L6208',
#  'L5834',
#  'L5545',
#  'L5543',
#  'L6282',
#  'L6278',
#  'L6215',
#  'L6213',
#  'L6206',
#  'L6190',
#  'L6183',
#  'L6156',
#  'L6132',
#  'L6020',
#  'L5933',
#  'L5924',
#  'L5922',
#  'L5820',
#  'L5817',
#  'L5815',
#  'L5809',
#  'L5804',
#  'L5801',
#  'L5794',
#  'L6308',
#  'L6302',
#  'L6297',
#  'L6289',
#  'L6267',
#  'L6237',
#  'L6066',
#  'L6062',
#  'L6057',
#  'L6051',
#  'L5958',
#  'L5954',
#  'L5949',
#  'L5946',
#  'L5943',
#  'L5900',
#  'L5869',
#  'L5858',
#  'L5824',
#  'L5728',
#  'L5722',
#  'L5539',
#  'L5537',
#  'L5534',
#  'L5531',
#  'L6313',
#  'L5585',
#  'L5573',
#  'L5568',
#  'L5560',
#  'L6254',
#  'L5773',
#  'L5767',
#  'L5479',
#  'L5448',
#  'L5443',
#  'L5441',
#  'L5406',
#  'L5404',
#  'L5399',
#  'L5396',
#  'L6219',
#  'L6011',
#  'L6006',
#  'L6004',
#  'L6002',
#  'L7001',
#  'L6996',
#  'L6986',
#  'L6980',
#  'L6977',
#  'L6971',
#  'L6960',
#  'L6957',
#  'L6429',
#  'L6361',
#  'L6351',
#  'L6347',
#  'L6337',
#  'L6335',
#  'L6607',
#  'L6605',
#  'L6909',
#  'L6707',
#  'L6863',
#  'L6858',
#  'L6852',
#  'L6844',
#  'L6840',
#  'L6833',
#  'L6830',
#  'L6828',
#  'L6814',
#  'L6810',
#  'L6803',
#  'L6800',
#  'L6791',
#  'L6789',
#  'L6781',
#  'L6779',
#  'L6935',
#  'L6911',
#  'L6906',
#  'L6865',
#  'L6847',
#  'L6460',
#  'L6453',
#  'L6443',
#  'L6437',
#  'L7070',
#  'L7061',
#  'L7059',
#  'L7048',
#  'L7043',
#  'L7034',
#  'L7026',
#  'L7018',
#  'L7016',
#  'L7013',
#  'L6919',
#  'L6693',
#  'L6686',
#  'L6921',
#  'L6902',
#  'L6900',
#  'L6898',
#  'L6890',
#  'L6886',
#  'L6881',
#  'L6868',
#  'L6374',
#  'L6823',
#  'L6821',
#  'L6816',
#  'L6787',
#  'L6768',
#  'L6762',
#  'L6757',
#  'L6753',
#  'L6750',
#  'L6722',
#  'L6623',
#  'L6614',
#  'L6597',
#  'L6576',
#  'L6574',
#  'L6570',
#  'L6568',
#  'L6558',
#  'L6556',
#  'L6546',
#  'L6747',
#  'L6738',
#  'L6648',
#  'L6643',
#  'L6639',
#  'L6425',
#  'L6419',
#  'L6412',
#  'L6410',
#  'L6407',
#  'L6402',
#  'L6399',
#  'L6395',
#  'L6389',
#  'L6386',
#  'L6384',
#  'L6382',
#  'L6372',
#  'L6368',
#  'L7088',
#  'L7085',
#  'L7081',
#  'L6534',
#  'L6531',
#  'L6525',
#  'L6516',
#  'L6511',
#  'L6507',
#  'L6503',
#  'L6485',
#  'L6482',
#  'L6479',
#  'L6473',
#  'L6468',
#  'L6466',
#  'L6669',
#  'L6665',
#  'L6661',
#  'L6657',
#  'L6358',
#  'L6354',
#  'L6682',
#  'L6679',
#  'L6676',
#  'L8206',
#  'L8203',
#  'L8200',
#  'L8196',
#  'L8155',
#  'L8094',
#  ...]

# %%
corpus.get_conversation('L984')
# Out:
# Conversation({'obj_type': 'conversation', 'meta': {'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"}, 'vectors': [], 'tree': None, 'owner': <convokit.model.corpus.Corpus object at 0x1246a5760>, 'id': 'L984'})

# %%
utt = corpus.random_utterance()

# %%
utt.text
# Out:
# '...cannot go on the air.'

# %%
corpus.corpus_dirpath
# Out:
# '/Users/ara/.convokit/downloads/movie-corpus'
